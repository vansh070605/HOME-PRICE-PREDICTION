# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("insurance_data.csv")
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.scatter(df.age,df.bought_insurance,marker='+', color='red')

# %%
df.shape
# Out:
# (27, 2)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['age']], df.bought_insurance, random_state=1)

# %%
X_test
# Out:
#     age
# 17   58
# 14   49
# 18   19
# 3    52
# 23   45
# 10   18
# 20   21

# %%
X_train
# Out:
#     age
# 21   26
# 4    46
# 2    47
# 22   40
# 6    55
# 19   18
# 13   29
# 7    60
# 24   50
# 1    25
# 16   25
# 0    22
# 15   55
# 26   23
# 25   54
# 9    61
# 8    62
# 12   27
# 11   28
# 5    56

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([1, 1, 0, 1, 1, 0, 0])

# %%
model.score(X_test, y_test)
# Out:
# 0.8571428571428571

# %%
model.predict_proba(X_test)
# Out:
# array([[0.04990851, 0.95009149],
#        [0.15909705, 0.84090295],
#        [0.93127156, 0.06872844],
#        [0.10986734, 0.89013266],
#        [0.25059366, 0.74940634],
#        [0.93984363, 0.06015637],
#        [0.91065275, 0.08934725]])
